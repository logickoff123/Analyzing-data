# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Covid Data.csv')
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0                1   65         2         2     2       2        2
# 1                1   72        97         2     2       2        2
# 2                2   55        97         1     2       2        2
# 3                2   53         2         2     2       2        2
# 4                2   68        97         1     2       2        2
# ...            ...  ...       ...       ...   ...     ...      ...
# 1048570          2   40        97         2     2       2        2
# 1048571          2   51        97         2     2       2        2
# 1048572          2   55        97         2     2       2        2
# 1048573          2   28        97         2     2       2        2
# 1048574          2   52        97         2     2       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU
# 0              2                     3   97
# 1              2                     5   97
# 2              2                     3    2
# 3              2                     7   97
# 4              2                     3   97
# ...          ...                   ...  ...
# 1048570        2                     7   97
# 1048571        2                     7    2
# 1048572        2                     7   97
# 1048573        2                     7   97
# 1048574        2                     7   97
#
# [1048575 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
df.isnull().sum() # Смотрим чтобы не было пропавших элементов
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'], errors ='coerce')
df['DATE_DIED'] = df['DATE_DIED'].dt.date
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  2020-03-05       97
# 1            2             1    2             1  2020-03-06       97
# 2            2             1    2             2  2020-09-06        1
# 3            2             1    1             1  2020-12-06       97
# 4            2             1    2             1         NaT       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1         NaT       97
# 1048571      1            13    2             2         NaT        2
# 1048572      2            13    2             1         NaT       97
# 1048573      2            13    2             1         NaT       97
# 1048574      2            13    2             1         NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0                1   65         2         2     2       2        2
# 1                1   72        97         2     2       2        2
# 2                2   55        97         1     2       2        2
# 3                2   53         2         2     2       2        2
# 4                2   68        97         1     2       2        2
# ...            ...  ...       ...       ...   ...     ...      ...
# 1048570          2   40        97         2     2       2        2
# 1048571          2   51        97         2     2       2        2
# 1048572          2   55        97         2     2       2        2
# 1048573          2   28        97         2     2       2        2
# 1048574          2   52        97         2     2       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU
# 0              2                     3   97
# 1              2                     5   97
# 2              2                     3    2
# 3              2                     7   97
# 4              2                     3   97
# ...          ...                   ...  ...
# 1048570        2                     7   97
# 1048571        2                     7    2
# 1048572        2                     7   97
# 1048573        2                     7   97
# 1048574        2                     7   97
#
# [1048575 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             30492 non-null    object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
df['STATUS'] = df['DATE_DIED'].copy(deep=False)
df['STATUS'] = df['STATUS'].fillna(1)
df.loc[df['STATUS'] !=1, 'STATUS'] =0 # изучить возможность loc


df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  2020-03-05       97
# 1            2             1    2             1  2020-03-06       97
# 2            2             1    2             2  2020-09-06        1
# 3            2             1    1             1  2020-12-06       97
# 4            2             1    2             1         NaT       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1         NaT       97
# 1048571      1            13    2             2         NaT        2
# 1048572      2            13    2             1         NaT       97
# 1048573      2            13    2             1         NaT       97
# 1048574      2            13    2             1         NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0                1   65         2         2     2       2        2
# 1                1   72        97         2     2       2        2
# 2                2   55        97         1     2       2        2
# 3                2   53         2         2     2       2        2
# 4                2   68        97         1     2       2        2
# ...            ...  ...       ...       ...   ...     ...      ...
# 1048570          2   40        97         2     2       2        2
# 1048571          2   51        97         2     2       2        2
# 1048572          2   55        97         2     2       2        2
# 1048573          2   28        97         2     2       2        2
# 1048574          2   52        97         2     2       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU STATUS
# 0              2                     3   97      0
# 1              2                     5   97      0
# 2              2                     3    2      0
# 3              2                     7   97      0
# 4              2                     3   97      1
# ...          ...                   ...  ...    ...
# 1048570        2                     7   97      1
# 1048571        2                     7    2      1
# 1048572        2                     7   97      1
# 1048573        2                     7   97      1
# 1048574        2                     7   97      1
#
# [1048575 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)
print(df)
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  2020-03-05       97
# 1            2             1    2             1  2020-03-06       97
# 2            2             1    2             2  2020-09-06        1
# 3            2             1    1             1  2020-12-06       97
# 4            2             1    2             1         NaT       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1         NaT       97
# 1048571      1            13    2             2         NaT        2
# 1048572      2            13    2             1         NaT       97
# 1048573      2            13    2             1         NaT       97
# 1048574      2            13    2             1         NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  \
# 0                1   65         2         2     2       2        2
# 1                1   72        97         2     2       2        2
# 2                2   55        97         1     2       2        2
# 3                2   53         2         2     2       2        2
# 4                2   68        97         1     2       2        2
# ...            ...  ...       ...       ...   ...     ...      ...
# 1048570          2   40        97         2     2       2        2
# 1048571          2   51        97         2     2       2        2
# 1048572          2   55        97         2     2       2        2
# 1048573          2   28        97         2     2       2        2
# 1048574          2   52        97         2     2       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 0                   1              2               2        2              2
# 1                   1              2               2        1              1
# 2                   2              2               2        2              2
# 3                   2              2               2        2              2
# 4                   1              2               2        2              2
# ...               ...            ...             ...      ...            ...
# 1048570             2              2               2        2              2
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# 1048573             2              2               2        2              2
# 1048574             2              2               2        2              2
#
#          TOBACCO  CLASIFFICATION_FINAL  ICU STATUS
# 0              2                     3   97      0
# 1              2                     5   97      0
# 2              2                     3    2      0
# 3              2                     7   97      0
# 4              2                     3   97      1
# ...          ...                   ...  ...    ...
# 1048570        2                     7   97      1
# 1048571        2                     7    2      1
# 1048572        2                     7   97      1
# 1048573        2                     7   97      1
# 1048574        2                     7   97      1
#
# [1048575 rows x 22 columns]

# %%
count_dead = (df['STATUS'] == 0).sum()
count_live = (df['STATUS'] == 1).sum()
print(count_dead)
print(count_live)
# Out:
# 30492
# 1018083

# %%
# Круговая  диаграмма сколько живых и мертвых

status_counts = df['STATUS'].value_counts()

# Создание круговой диаграммы
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=['Жив', 'Мертв'], autopct='%1.1f%%', startangle=90)
plt.title('Распределение по статусу')
plt.axis('equal')  # Чтобы круговая диаграмма была кругом
plt.show()

# %%
# Круговая  диаграмма сколько живых и мертвых

status_counts = df['STATUS'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(
    status_counts, 
    labels=['Жив', 'Мертв'], 
    autopct='%1.1f%%', 
    startangle=55,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},
    textprops={'fontsize': 14, "weight":"bold"},
    explode=[0.5, 0])

plt.title('Распределение по статусу', fontsize=16, weight='bold')
plt.legend(['Жив', 'Мертв'], loc="best", fontsize=12)
plt.axis('equal')  # Чтобы круговая диаграмма была кругом

plt.show()

# %%
# количество женщин и мужчин болевших ковидом

covid_women = df.loc[(df['STATUS']==0) & (df['SEX'] == 1)]
covid_men = df.loc[(df['STATUS'] == 0) & (df['SEX'] == 2)]


status_covid_women = covid_women.shape[0]
status_covid_men = covid_men.shape[0]

status_counts = pd.Series([status_covid_women, status_covid_men], index=['Women', 'Men'])

status_counts.plot(kind='bar', color=['pink', 'blue'])

# Добавляем заголовок и метки осей
plt.title('Количество ковидных женщин и мужчин')
plt.xlabel('Пол')
plt.ylabel('Количество')

# Показываем график
plt.show()

# %%
covid_women = df[(df['STATUS'] == 0) & (df['SEX'] == 1)]
covid_men = df[(df['STATUS'] == 0) & (df['SEX'] == 2)]

status_covid_women = covid_women.shape[0]
status_covid_men = covid_men.shape[0]

status_counts = pd.Series([status_covid_women, status_covid_men], index=['Женщины', 'Мужчины'])

plt.figure(figsize=(8, 6))
ax = status_counts.plot(kind='bar', color=['#ff99cc', '#66b3ff'], edgecolor='black')

plt.title('Количество ковидных женщин и мужчин', fontsize=16)
plt.xlabel('Пол', fontsize=14)
plt.ylabel('Количество заболевших', fontsize=14)

# Добавляем подписи к столбцам
for i, count in enumerate(status_counts):
    ax.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')

# Добавляем сетку для лучшей читаемости
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# Сколько беременных женщин было госпитализировано 

pregment_women_gospital = (df['PREGNANT'] == 1) & (df['PATIENT_TYPE'] == 2 )
pregment_woman_home = (df['PREGNANT'] == 1) & (df['PATIENT_TYPE'] == 1 )

const_pregment_women_gospital = pregment_women_gospital.shape[0]
const_pregment_woman_home = pregment_woman_home.shape[0]

status_pregment_women_gospital = pd.Series([const_pregment_women_gospital, const_pregment_woman_home], index=['Women_gospital', 'Women_home'])

status_pregment_women_gospital.plot(kind='bar', color=['orange', 'red'])


plt.title('Количество беременных женщин кого госпитолизировали и отпраыляли домой') # ик
plt.xlabel('Была ли госпитализация ')
plt.ylabel('Количество')

# Показываем график
plt.show()

# %%
pregnant_women_hospitalized = df[(df['PREGNANT'] == 1) & (df['PATIENT_TYPE'] == 2)]
pregnant_women_home = df[(df['PREGNANT'] == 1) & (df['PATIENT_TYPE'] == 1)]

count_pregnant_hospitalized = pregnant_women_hospitalized.shape[0]
count_pregnant_home = pregnant_women_home.shape[0]

status_pregnant_women = pd.Series([count_pregnant_hospitalized, count_pregnant_home], index=['Госпитализировано', 'Отправлено доомой'])

plt.figure(figsize=(8, 6))
ax = status_pregnant_women.plot(kind='bar', color=['#ffa500', '#ff6347'], edgecolor='black')

plt.title('Количестве беременных женщин Госпитализировано / Отправлено домой', fontsize=16)
plt.xlabel('Диагноз', fontsize=14)
plt.ylabel('Количество', fontsize=14)

# Добавляем подписи к столбцам
for i, count in enumerate(status_pregnant_women):
    ax.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ### Можем сделать распределение по возрасту заболевших

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.histplot(data=df, x='AGE', bins=30, kde=True, color='blue', edgecolor='black', alpha=0.7)

plt.title('Распределение пациентов по возрасту', fontsize=18, fontweight='bold')
plt.xlabel('Возраст', fontsize=14)
plt.ylabel('Количество', fontsize=14)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ### Можем проверить сколько уникальных значений признаков

# %%
for i in df.columns:
    print(i,"=>\t",len(df[i].unique())) # 121 тип возраста - возможно где-то проблемы, можно убрать возраст который >100
# Out:
# USMER =>	 2
# MEDICAL_UNIT =>	 13
# SEX =>	 2
# PATIENT_TYPE =>	 2
# DATE_DIED =>	 151
# INTUBED =>	 4
# PNEUMONIA =>	 3
# AGE =>	 121
# PREGNANT =>	 4
# DIABETES =>	 3
# COPD =>	 3
# ASTHMA =>	 3
# INMSUPR =>	 3
# HIPERTENSION =>	 3
# OTHER_DISEASE =>	 3
# CARDIOVASCULAR =>	 3
# OBESITY =>	 3
# RENAL_CHRONIC =>	 3
# TOBACCO =>	 3
# CLASIFFICATION_FINAL =>	 7
# ICU =>	 4
# STATUS =>	 2

# %%
df['PREGNANT'].value_counts() # Почему-то 4 типа беременности
# Out:
# PREGNANT
# 97    523511
# 2     513179
# 1       8131
# 98      3754
# Name: count, dtype: int64

# %% [markdown]
# #### Видим, что у некоторых столбцов, которые судя по описанию должны иметь бинарные признаки (болен диабетом или нет, беременна или нет), имеют по 3-4 признака. Это можно исправить:

# %% [markdown]
# #### SEX:
# #### 1 - female. 2 - male (из описания датасета)

# %%
print('MALE',df.query('SEX==2')['PREGNANT'].value_counts(), sep='\n') # Статус беременности мужиков
# Out:
# MALE
# PREGNANT
# 97    523511
# Name: count, dtype: int64

# %%
df['PREGNANT'] = df['PREGNANT'].replace(97,2) # Заменим лишние типы на "2" (предполагая, что статус "2" означаент "не беременна", раз он у большинства женщин)
df['PREGNANT'] = df['PREGNANT'].replace(98,2)

# %%
print('FEMALE',df.query('SEX==1')['PREGNANT'].value_counts(), sep='\n') # Статусы беременности женщин
# Out:
# FEMALE
# PREGNANT
# 2     513179
# 1       8131
# 98      3754
# Name: count, dtype: int64

# %%
df['PREGNANT'].value_counts()
# Out:
# PREGNANT
# 2    1040444
# 1       8131
# Name: count, dtype: int64

# %% [markdown]
# #### В целом в коде много где встречаются значения [97, 98, 99], которые скорее всего выступают в роли плейсхолдеров для неизвестных значений. В идеале просмотреть все классы где есть подобная проблема и либо заменить их на Nan, либо подогнать под другие значения там где это очевидно (как с беременностью)
